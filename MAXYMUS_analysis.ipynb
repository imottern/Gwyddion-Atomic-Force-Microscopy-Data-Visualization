# %%
import afm_csv_analysis as afm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
file = r"C:\Users\poeda\OneDrive\Desktop\Documents\Luo Group\AFM Images\CrsBr MTJ Project\MAXYMUS\MAXYMUS #4.013 main.csv"
fgt = afm.afmData(file).zero_minimums().select_profiles([1,2,3])
fgt.plotly_graph()

# %%
plat1 = fgt.data[
    ((fgt.data['position1'] >= 0) & (fgt.data['position1'] <= 230e-9)) |
    ((fgt.data['position1'] >= 4300e-9) & (fgt.data['position1'] <= 4780e-9))
]
plat2 = fgt.data[
    (fgt.data['position1'] >= 410e-9) & (fgt.data['position1'] <= 3840e-9)]
plat1_height = plat1['height1'].mean()
plat2_height = plat2['height1'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position1'].max())
place = 1000e-9

fgt.steps = {}
fgt.steps['Profile 1'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position2'] >= 0) & (fgt.data['position2'] <= 1150e-9)) |
    ((fgt.data['position2'] >= 5800e-9) & (fgt.data['position2'] <= 6370e-9))
]
plat2 = fgt.data[
    (fgt.data['position2'] >= 1750e-9) & (fgt.data['position2'] <= 5400e-9)]
plat1_height = plat1['height2'].mean()
plat2_height = plat2['height2'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position2'].max())
place = 2000e-9

fgt.steps['Profile 2'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position3'] >= 0) & (fgt.data['position3'] <= 800e-9)) |
    ((fgt.data['position3'] >= 4800e-9) & (fgt.data['position3'] <= 5300e-9))
]
plat2 = fgt.data[
    (fgt.data['position3'] >= 1000e-9) & (fgt.data['position3'] <= 4500e-9)]
plat1_height = plat1['height3'].mean()
plat2_height = plat2['height3'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position3'].max())
place = 3000e-9

fgt.steps['Profile 3'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
fgt.graph(grid=False, title=False)
fgt.graph(grid=False, title=False, show_steps=True)
mean = fgt.average_profiles()
plt.plot(mean['mean_position'], mean['height_avg'], color='black')

# %%
electrodes = afm.afmData(file).zero_minimums().select_profiles([4,5,6])
electrodes.plotly_graph()

# %%
big_file = r"C:\Users\poeda\OneDrive\Desktop\Documents\Luo Group\AFM Images\CrsBr MTJ Project\MAXYMUS\MAXYMUS #4.013 big.csv"
fgt = afm.afmData(big_file).zero_minimums()
fgt.plotly_graph()

# %%
plat1 = fgt.data[
    ((fgt.data['position1'] >= 0) & (fgt.data['position1'] <= 150e-9)) |
    ((fgt.data['position1'] >= 4500e-9) & (fgt.data['position1'] <= 4840e-9))
]
plat2 = fgt.data[
    (fgt.data['position1'] >= 600e-9) & (fgt.data['position1'] <= 4000e-9)]
plat1_height = plat1['height1'].mean()
plat2_height = plat2['height1'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position1'].max())
place = 1000e-9

fgt.steps = {}
fgt.steps['Profile 1'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position2'] >= 0) & (fgt.data['position2'] <= 350e-9)) |
    ((fgt.data['position2'] >= 4500e-9) & (fgt.data['position2'] <= 4900e-9))
]
plat2 = fgt.data[
    (fgt.data['position2'] >= 650e-9) & (fgt.data['position2'] <= 4200e-9)]
plat1_height = plat1['height2'].mean()
plat2_height = plat2['height2'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position2'].max())
place = 1000e-9

fgt.steps['Profile 2'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position3'] >= 0) & (fgt.data['position3'] <= 200e-9)) |
    ((fgt.data['position3'] >= 4470e-9) & (fgt.data['position3'] <= 4900e-9))
]
plat2 = fgt.data[
    ((fgt.data['position3'] >= 550) & (fgt.data['position3'] <= 1190e-9)) |
    ((fgt.data['position3'] >= 1950e-9) & (fgt.data['position3'] <= 4300e-9))
]
plat1_height = plat1['height3'].mean()
plat2_height = plat2['height3'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position3'].max())
place = 1000e-9

fgt.steps['Profile 3'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position4'] >= 0) & (fgt.data['position4'] <= 400e-9)) |
    ((fgt.data['position4'] >= 5000e-9) & (fgt.data['position4'] <= 5150e-9))
]
plat2 = fgt.data[
    ((fgt.data['position4'] >= 550) & (fgt.data['position4'] <= 1200e-9)) |
    ((fgt.data['position4'] >= 1950e-9) & (fgt.data['position4'] <= 4750e-9))
]
plat1_height = plat1['height4'].mean()
plat2_height = plat2['height4'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position4'].max())
place = 1000e-9

fgt.steps['Profile 4'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position5'] >= 4470e-9) & (fgt.data['position5'] <= 4920e-9))
]
plat2 = fgt.data[
    ((fgt.data['position5'] >= 1850e-9) & (fgt.data['position5'] <= 4200e-9))
]
plat1_height = plat1['height5'].mean()
plat2_height = plat2['height5'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position5'].max())
place = 1000e-9

fgt.steps['Profile 5'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position6'] >= 0) & (fgt.data['position6'] <= 520e-9)) |
    ((fgt.data['position6'] >= 5180e-9) & (fgt.data['position6'] <= 5500e-9))
]
plat2 = fgt.data[
    ((fgt.data['position6'] >= 900e-9) & (fgt.data['position6'] <= 4700e-9))
]
plat1_height = plat1['height6'].mean()
plat2_height = plat2['height6'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position6'].max())
place = 1000e-9

fgt.steps['Profile 6'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position7'] >= 0) & (fgt.data['position7'] <= 250e-9)) |
    ((fgt.data['position7'] >= 5100e-9) & (fgt.data['position7'] <= 5700e-9))
]
plat2 = fgt.data[
    ((fgt.data['position7'] >= 2300e-9) & (fgt.data['position7'] <= 4700e-9))
]
plat1_height = plat1['height7'].mean()
plat2_height = plat2['height7'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position7'].max())
place = 1000e-9

fgt.steps['Profile 7'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position8'] >= 0) & (fgt.data['position8'] <= 200e-9)) |
    ((fgt.data['position8'] >= 5700e-9) & (fgt.data['position8'] <= 6300e-9))
]
plat2 = fgt.data[
    ((fgt.data['position8'] >= 450e-9) & (fgt.data['position8'] <= 5000e-9))
]
plat1_height = plat1['height8'].mean()
plat2_height = plat2['height8'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position8'].max())
place = 1000e-9

fgt.steps['Profile 8'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position9'] >= 5400e-9) & (fgt.data['position9'] <= 5920e-9))
]
plat2 = fgt.data[
    ((fgt.data['position9'] >= 420e-9) & (fgt.data['position9'] <= 4750e-9))
]
plat1_height = plat1['height9'].mean()
plat2_height = plat2['height9'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position9'].max())
place = 1000e-9

fgt.steps['Profile 9'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position10'] >= 5170e-9) & (fgt.data['position10'] <= 6200e-9))
]
plat2 = fgt.data[
    ((fgt.data['position10'] >= 800e-9) & (fgt.data['position10'] <= 4750e-9))
]
plat1_height = plat1['height10'].mean()
plat2_height = plat2['height10'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position10'].max())
place = 1000e-9

fgt.steps['Profile 10'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position11'] >= 0) & (fgt.data['position11'] <= 600e-9)) |
    ((fgt.data['position11'] >= 4800e-9) & (fgt.data['position11'] <= 5700e-9))
]
plat2 = fgt.data[
    ((fgt.data['position11'] >= 850e-9) & (fgt.data['position11'] <= 4300e-9))
]
plat1_height = plat1['height11'].mean()
plat2_height = plat2['height11'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position11'].max())
place = 1000e-9

fgt.steps['Profile 11'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position12'] >= 0) & (fgt.data['position12'] <= 450e-9)) |
    ((fgt.data['position12'] >= 4100e-9) & (fgt.data['position12'] <= 4700e-9))
]
plat2 = fgt.data[
    ((fgt.data['position12'] >= 650e-9) & (fgt.data['position12'] <= 3800e-9))
]
plat1_height = plat1['height12'].mean()
plat2_height = plat2['height12'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position12'].max())
place = 1000e-9

fgt.steps['Profile 12'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position13'] >= 0) & (fgt.data['position13'] <= 350e-9)) |
    ((fgt.data['position13'] >= 3200e-9) & (fgt.data['position13'] <= 4000e-9))
]
plat2 = fgt.data[
    ((fgt.data['position13'] >= 700e-9) & (fgt.data['position13'] <= 2800e-9))
]
plat1_height = plat1['height13'].mean()
plat2_height = plat2['height13'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position13'].max())
place = 1000e-9

fgt.steps['Profile 13'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = fgt.data[
    ((fgt.data['position14'] >= 0) & (fgt.data['position14'] <= 250e-9)) |
    ((fgt.data['position14'] >= 2600e-9) & (fgt.data['position14'] <= 3000e-9))
]
plat2 = fgt.data[
    ((fgt.data['position14'] >= 1500e-9) & (fgt.data['position14'] <= 2300e-9))
]
plat1_height = plat1['height14'].mean()
plat2_height = plat2['height14'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position14'].max())
place = 1000e-9

fgt.steps['Profile 14'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
values = []

for i in fgt.steps:
    values.append(fgt.steps[i]['step_height'])
mean_value = np.mean(values)
print(mean_value)

plt.hist(values, bins=10)
# Out:
# 9.600078415157966e-09
# (array([2., 1., 4., 3., 1., 0., 2., 0., 0., 1.]),
#  array([7.43469001e-09, 8.04324901e-09, 8.65180801e-09, 9.26036702e-09,
#         9.86892602e-09, 1.04774850e-08, 1.10860440e-08, 1.16946030e-08,
#         1.23031620e-08, 1.29117210e-08, 1.35202800e-08]),
#  <BarContainer object of 10 artists>)

# %%
more_file = r"C:\Users\poeda\OneDrive\Desktop\Documents\Luo Group\AFM Images\CrsBr MTJ Project\MAXYMUS\MAXYMUS #4.013 more.csv"
more_fgt = afm.afmData(more_file).zero_minimums()
more_fgt.plotly_graph()

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position1'] >= 0) & (more_fgt.data['position1'] <= 430e-9)) |
    ((more_fgt.data['position1'] >= 2800e-9) & (more_fgt.data['position1'] <= 3000e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position1'] >= 605e-9) & (more_fgt.data['position1'] <= 1760e-9))
]
plat1_height = plat1['height1'].mean()
plat2_height = plat2['height1'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position1'].max())
place = 1000e-9

more_fgt.steps = {}

more_fgt.steps['Profile 1'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position2'] >= 0) & (more_fgt.data['position2'] <= 600e-9)) |
    ((more_fgt.data['position2'] >= 3300e-9) & (more_fgt.data['position2'] <= 3000e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position2'] >= 900e-9) & (more_fgt.data['position2'] <= 1760e-9))
]
plat1_height = plat1['height2'].mean()
plat2_height = plat2['height2'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position2'].max())
place = 1000e-9

more_fgt.steps['Profile 2'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position3'] >= 0) & (more_fgt.data['position3'] <= 700e-9)) |
    ((more_fgt.data['position3'] >= 3800e-9) & (more_fgt.data['position3'] <= 4000e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position3'] >= 1000e-9) & (more_fgt.data['position3'] <= 2000e-9))
]
plat1_height = plat1['height3'].mean()
plat2_height = plat2['height3'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position3'].max())
place = 1000e-9

more_fgt.steps['Profile 3'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position4'] >= 0) & (more_fgt.data['position4'] <= 720e-9)) |
    ((more_fgt.data['position4'] >= 3900e-9) & (more_fgt.data['position4'] <= 4200e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position4'] >= 1000e-9) & (more_fgt.data['position4'] <= 2200e-9)) |
    ((more_fgt.data['position4'] >= 3000e-9) & (more_fgt.data['position4'] <= 3700e-9))
]
plat1_height = plat1['height4'].mean()
plat2_height = plat2['height4'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position4'].max())
place = 1000e-9

more_fgt.steps['Profile 4'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position5'] >= 100e-9) & (more_fgt.data['position5'] <= 720e-9)) |
    ((more_fgt.data['position5'] >= 4100e-9) & (more_fgt.data['position5'] <= 4700e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position5'] >= 940e-9) & (more_fgt.data['position5'] <= 2300e-9)) |
    ((more_fgt.data['position5'] >= 3400e-9) & (more_fgt.data['position5'] <= 3800e-9))
]
plat1_height = plat1['height5'].mean()
plat2_height = plat2['height5'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position5'].max())
place = 1000e-9

more_fgt.steps['Profile 5'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position6'] >= 0e-9) & (more_fgt.data['position6'] <= 600e-9)) |
    ((more_fgt.data['position6'] >= 4500e-9) & (more_fgt.data['position6'] <= 4800e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position6'] >= 875e-9) & (more_fgt.data['position6'] <= 2000e-9)) |
    ((more_fgt.data['position6'] >= 2700e-9) & (more_fgt.data['position6'] <= 4300e-9))
]
plat1_height = plat1['height6'].mean()
plat2_height = plat2['height6'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position6'].max())
place = 1000e-9

more_fgt.steps['Profile 6'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position7'] >= 0e-9) & (more_fgt.data['position7'] <= 600e-9)) |
    ((more_fgt.data['position7'] >= 4700e-9) & (more_fgt.data['position7'] <= 5200e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position7'] >= 750e-9) & (more_fgt.data['position7'] <= 2100e-9)) |
    ((more_fgt.data['position7'] >= 3000e-9) & (more_fgt.data['position7'] <= 4000e-9))
]
plat1_height = plat1['height7'].mean()
plat2_height = plat2['height7'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position7'].max())
place = 1000e-9

more_fgt.steps['Profile 7'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position8'] >= 0e-9) & (more_fgt.data['position8'] <= 400e-9))]
plat2 = more_fgt.data[
    ((more_fgt.data['position8'] >= 600e-9) & (more_fgt.data['position8'] <= 2000e-9)) |
    ((more_fgt.data['position8'] >= 2600e-9) & (more_fgt.data['position8'] <= 4000e-9))
]
plat1_height = plat1['height8'].mean()
plat2_height = plat2['height8'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position8'].max())
place = 1000e-9

more_fgt.steps['Profile 8'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position9'] >= 0e-9) & (more_fgt.data['position9'] <= 450e-9)) |
    ((more_fgt.data['position9'] >= 5500e-9) & (more_fgt.data['position9'] <= 6200e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position9'] >= 600e-9) & (more_fgt.data['position9'] <= 2300e-9)) |
    ((more_fgt.data['position9'] >= 2800e-9) & (more_fgt.data['position9'] <= 4000e-9))
]
plat1_height = plat1['height9'].mean()
plat2_height = plat2['height9'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position9'].max())
place = 1000e-9

more_fgt.steps['Profile 9'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position10'] >= 0e-9) & (more_fgt.data['position10'] <= 300e-9)) |
    ((more_fgt.data['position10'] >= 3500e-9) & (more_fgt.data['position10'] <= 3900e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position10'] >= 500e-9) & (more_fgt.data['position10'] <= 1900e-9)) |
    ((more_fgt.data['position10'] >= 2200e-9) & (more_fgt.data['position10'] <= 3000e-9))
]
plat1_height = plat1['height10'].mean()
plat2_height = plat2['height10'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position10'].max())
place = 1000e-9

more_fgt.steps['Profile 10'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position11'] >= 0e-9) & (more_fgt.data['position11'] <= 150e-9)) |
    ((more_fgt.data['position11'] >= 4300e-9) & (more_fgt.data['position11'] <= 4800e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position11'] >= 400e-9) & (more_fgt.data['position11'] <= 2000e-9)) |
    ((more_fgt.data['position11'] >= 2400e-9) & (more_fgt.data['position11'] <= 3800e-9))
]
plat1_height = plat1['height11'].mean()
plat2_height = plat2['height11'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position11'].max())
place = 1000e-9

more_fgt.steps['Profile 11'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position12'] >= 0e-9) & (more_fgt.data['position12'] <= 200e-9)) |
    ((more_fgt.data['position12'] >= 4700e-9) & (more_fgt.data['position12'] <= 5200e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position12'] >= 500e-9) & (more_fgt.data['position12'] <= 2300e-9)) |
    ((more_fgt.data['position12'] >= 2600e-9) & (more_fgt.data['position12'] <= 4200e-9))
]
plat1_height = plat1['height12'].mean()
plat2_height = plat2['height12'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position12'].max())
place = 1000e-9

more_fgt.steps['Profile 12'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position13'] >= 0e-9) & (more_fgt.data['position13'] <= 100e-9)) |
    ((more_fgt.data['position13'] >= 4800e-9) & (more_fgt.data['position13'] <= 5100e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position13'] >= 500e-9) & (more_fgt.data['position13'] <= 2500e-9)) |
    ((more_fgt.data['position13'] >= 2900e-9) & (more_fgt.data['position13'] <= 4000e-9))
]
plat1_height = plat1['height13'].mean()
plat2_height = plat2['height13'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position13'].max())
place = 1000e-9

more_fgt.steps['Profile 13'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position14'] >= 50e-9) & (more_fgt.data['position14'] <= 200e-9)) |
    ((more_fgt.data['position14'] >= 5400e-9) & (more_fgt.data['position14'] <= 5500e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position14'] >= 800e-9) & (more_fgt.data['position14'] <= 2600e-9)) |
    ((more_fgt.data['position14'] >= 3000e-9) & (more_fgt.data['position14'] <= 5000e-9))
]
plat1_height = plat1['height14'].mean()
plat2_height = plat2['height14'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position14'].max())
place = 1000e-9

more_fgt.steps['Profile 14'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position15'] >= 0e-9) & (more_fgt.data['position15'] <= 500e-9)) |
    ((more_fgt.data['position15'] >= 6400e-9) & (more_fgt.data['position15'] <= 6600e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position15'] >= 800e-9) & (more_fgt.data['position15'] <= 3000e-9)) |
    ((more_fgt.data['position15'] >= 3500e-9) & (more_fgt.data['position15'] <= 4400e-9))
]
plat1_height = plat1['height15'].mean()
plat2_height = plat2['height15'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position15'].max())
place = 1000e-9

more_fgt.steps['Profile 15'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position16'] >= 0e-9) & (more_fgt.data['position16'] <= 450e-9)) |
    ((more_fgt.data['position16'] >= 4300e-9) & (more_fgt.data['position16'] <= 4860e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position16'] >= 800e-9) & (more_fgt.data['position16'] <= 3300e-9))]
plat1_height = plat1['height16'].mean()
plat2_height = plat2['height16'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position16'].max())
place = 1000e-9

more_fgt.steps['Profile 16'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position17'] >= 1500e-9) & (more_fgt.data['position17'] <= 500e-9)) |
    ((more_fgt.data['position17'] >= 4500e-9) & (more_fgt.data['position17'] <= 5000e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position17'] >= 2000e-9) & (more_fgt.data['position17'] <= 4200e-9))
]
plat1_height = plat1['height17'].mean()
plat2_height = plat2['height17'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position17'].max())
place = 1000e-9

more_fgt.steps['Profile 17'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
plat1 = more_fgt.data[
    ((more_fgt.data['position18'] >= 0e-9) & (more_fgt.data['position18'] <= 700e-9)) |
    ((more_fgt.data['position18'] >= 4700e-9) & (more_fgt.data['position18'] <= 5000e-9))
]
plat2 = more_fgt.data[
    ((more_fgt.data['position18'] >= 2600e-9) & (more_fgt.data['position18'] <= 4200e-9))
]
plat1_height = plat1['height18'].mean()
plat2_height = plat2['height18'].mean()
height = plat2_height - plat1_height
range = (0, plat1['position18'].max())
place = 1000e-9

more_fgt.steps['Profile 18'] = {
    "step_height": height,
    "x_step": place,
    "plateau1_mean": plat1_height, 
    "plateau2_mean": plat2_height,
    "plateau1_range": range,
    "plateau2_range": range}

# %%
for i in more_fgt.steps:
    values.append(more_fgt.steps[i]['step_height'])
mean_value = np.mean(values)
print(mean_value)

plt.hist(values, bins=10)
# Out:
# 1.0359378323108052e-08
# (array([ 8., 13., 22., 16., 18.,  0., 20., 12.,  7.,  6.]),
#  array([7.03220524e-09, 7.77257891e-09, 8.51295259e-09, 9.25332627e-09,
#         9.99369994e-09, 1.07340736e-08, 1.14744473e-08, 1.22148210e-08,
#         1.29551946e-08, 1.36955683e-08, 1.44359420e-08]),
#  <BarContainer object of 10 artists>)
