# %%
import numpy as np
import matplotlib.pyplot as plt
import afm_functions as afm

# %% [markdown]
# Nice Graphs

# %%
data = afm.import_data(r"C:\Users\poeda\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #2.009 heights")
fig, df = afm.plotly_graph(data)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = afm.import_data(r"C:\Users\poeda\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #2.009 heights")
#       2 fig, df = afm.plotly_graph(data)
#       3 fig.show()
#
# File c:\Users\poeda\OneDrive\Desktop\Documents\Luo Group\Luo Group Code\AFM Workflow\afm_functions.py:11, in import_data(file)
#      10 def import_data(file):
# ---> 11     numbers = pd.read_csv(file,delimiter=';')
#      12     numbers = numbers.dropna(axis=1, how='all')
#      13     data = np.array(numbers)
#
# ...

# %%
data2 = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #2.014 heights.csv")
fig2, df2 = afm.plotly_graph(data2)
fig2.show()

# %%
data3 = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #3.005 heights.csv")
fig3, df3 = afm.plotly_graph(data3)
fig3.show()

avg_data3 = afm.threshold_averaging(data3, 0.1e-8)
avg_fig3, avg_df3 = afm.plotly_graph(avg_data3)
avg_fig3.show()

# %%
profile = [3]
result_dict = {}
for i in profile:
    x_data, y_data = afm.scatter_data(avg_data3, i)
    afm.select_nearest_points_with_sliders(x_data, y_data, result_dict, i, 'CrSBr MTJ')
# Out:
# ...
# Output()
# Button(button_style='success', description='Confirm Selection', style=ButtonStyle())
# Output()

# %%
for i in result_dict:
    print(float(i))
print(result_dict)
# Out:
# 3.0
# {3: {'fig': <Figure size 640x480 with 1 Axes>, 'height': np.float64(3.0143069564102545)}}

# %%
print(7.311 - 4.297)
print((7.311 - 4.297)/.7959)
# Out:
# 3.0140000000000002
# 3.78690790300289

# %%
data4 = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #3 crsbr height")
fig4, df4 = afm.plotly_graph(data4)
fig4.show()

avg_data4 = afm.threshold_averaging(data4, 0.1e-8)
avg_fig4, avg_df4 = afm.plotly_graph(avg_data4)
avg_fig4.show()

# %%
profile = [1,2,3,4]
result_dict = {}
for i in profile:
    x_data, y_data = afm.scatter_data(avg_data4, i)
    afm.select_nearest_points_with_sliders(x_data, y_data, result_dict, i, 'CrSBr MTJ')
# Out:
# ...
# Output()
# Button(button_style='success', description='Confirm Selection', style=ButtonStyle())
# Output()
# ...
# Output()
# Button(button_style='success', description='Confirm Selection', style=ButtonStyle())
# Output()
# ...
# Output()
# Button(button_style='success', description='Confirm Selection', style=ButtonStyle())
# Output()
# ...
# Output()
# Button(button_style='success', description='Confirm Selection', style=ButtonStyle())
# Output()

# %%
print(result_dict)
# Out:
# {1: {'fig': <Figure size 640x480 with 1 Axes>, 'height': np.float64(2.8591433928571384)}, 2: {'fig': <Figure size 640x480 with 1 Axes>, 'height': np.float64(2.341353625)}, 3: {'fig': <Figure size 640x480 with 1 Axes>, 'height': np.float64(3.23392755555556)}, 4: {'fig': <Figure size 640x480 with 1 Axes>, 'height': np.float64(2.686421799999998)}}

# %%
data5 = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #3.005 heights andrew.csv")
fig5, df5 = afm.plotly_graph(data5)
fig5.show()

avg_data5 = afm.threshold_averaging(data5, 0.1e-10)
avg_fig5, avg_df5 = afm.plotly_graph(avg_data5)
avg_fig5.show()

# %%
mtj_4 = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #4.005 heights.csv")
fig6, df6 = afm.plotly_graph(mtj_4)
fig6.show()

mtj_4_avg = afm.threshold_averaging(mtj_4, 1e-9)
mtj_4_avg_fig, mtj_4_avg_df = afm.plotly_graph(mtj_4_avg)
mtj_4_avg_fig.show()

# %% [markdown]
# TaIrTe ~ 18nm
# CrSBr ~ 3-4nm
# Graphene ~ 8nm

# %%
mtj_3_post = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #3 Post.004 height.csv")
fig3_post, df3_post = afm.plotly_graph(mtj_3_post)
fig3_post.show()

mtj_3_post_avg = afm.threshold_averaging(mtj_3_post, 1e-9)
mtj_3_post_avg_fig, mtj_3_avg_post_df = afm.plotly_graph(mtj_3_post_avg)
mtj_3_post_avg_fig.show()

# %% [markdown]
# - 1: 4.2
# - 2: 4.5
# - 3: 4.1
# - 4: 4.8
# - 5: 4.8
# - 6: 4.7
# - 7: 3.6
# - Graphene: 12.4

# %%
mtj_3_post2 = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\CrsBr MTJ Project\CrSBr MTJ #3 Post.005 hieghts.csv")
fig3_post2, df3_post2 = afm.plotly_graph(mtj_3_post2)
fig3_post2.show()

mtj_3_post2_avg = afm.threshold_averaging(mtj_3_post2, 1e-9)
mtj_3_post2_avg_fig, mtj_3_avg_post2_df = afm.plotly_graph(mtj_3_post2_avg)
mtj_3_post2_avg_fig.show()

# %%
ptte = afm.import_data(r"C:\Users\poeda\OneDrive\Documents\Luo Group\AFM Images\TRT PtTe\Kyle Data\PtTe1.017 profiles.csv")
ptte_fig, ptte_df = afm.plotly_graph(ptte)
ptte_fig.show()

ptte_avg = afm.threshold_averaging(ptte, 2e-9)
ptte_avg_fig, ptte_avg_df = afm.plotly_graph(ptte_avg)
ptte_avg_fig.show()
